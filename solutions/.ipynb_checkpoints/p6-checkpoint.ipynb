# %% [markdown]
# # DMG2 Assignment : Problem 6

# %% [markdown]
# _Naive Bayes Text Classifier_

# %% [markdown]
# Number of classes : 20
#
# In each class, there are a number of documents, each one corresponding to a date. The test-train split will be based on the date.
#
# **Preprocessing in each document :**
# * Keep only From, Subject, Host, Organization, Data
# * Remove special characters, stop words
# * Stem the words
# * There are numbers in the data, as addresses, phone numbers, currency, etc. Should they be removed?

# %%
import os,re
import pandas as pd
import numpy as np
import nltk,unicodedata
import operator,math

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.lancaster import LancasterStemmer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Reading Files

# %%
DATA_DIR = '/home/jishnu/Documents/ISB/Term3/dmg2/assignments/hw_assignment1/dmg2/datasets/20_newsgroups'

# %%
labels,files_list = [],[]
for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        labels.append(re.sub(r'/home/jishnu/Documents/ISB/Term3/dmg2/assignments/hw_assignment1/dmg2/datasets/20_newsgroups/','',root))
        files_list.append(os.path.join(root,file))

# %%
files_df = pd.DataFrame({'filename':files_list, 'label' : labels})
list(files_df['label'].unique())
# Out:
# ['comp.graphics',
#  'talk.religion.misc',
#  'rec.sport.baseball',
#  'comp.sys.ibm.pc.hardware',
#  'rec.motorcycles',
#  'talk.politics.guns',
#  'misc.forsale',
#  'alt.atheism',
#  'talk.politics.misc',
#  'talk.politics.mideast',
#  'rec.autos',
#  'comp.windows.x',
#  'sci.crypt',
#  'sci.electronics',
#  'soc.religion.christian',
#  'rec.sport.hockey',
#  'comp.os.ms-windows.misc',
#  'sci.space',
#  'comp.sys.mac.hardware',
#  'sci.med']

# %% [markdown]
# ## Train - Test Split

# %% [markdown]
# For each class, splitting the documents to training and test based on a 70-30 rule.

# %%
train = pd.DataFrame(columns=['filename','label'])
test = pd.DataFrame(columns=['filename','label'])

for label in list(files_df['label'].unique()):
    threshold = files_df.loc[files_df['label'] == label].shape[0] * 0.7
    threshold = int(np.floor(threshold))
    train = train.append(files_df.loc[files_df['label'] == label].iloc[:threshold,:],ignore_index=True)
    test = test.append(files_df.loc[files_df['label'] == label].iloc[threshold:,:],ignore_index=True)

print(train.shape[0],test.shape[0])
# Out:
# 13997 6000

# %% [markdown]
# ## Creating dictionary of 5000 most frequent words in each class

# %% [markdown]
# Calculating P(W|C) for each word in each class, by normalizing using Laplace smoothing parameter of 30.
#
# Here, CountVectorizer class from scikit-learn has been used to create the Document-Term Matrix. The class has an inbuilt preprocessing module.
# After calculating the document term matrix, the counts of document in which each word occurs has been calculated to find the most frequent ones for each class. Then, the probability of word given class has been calculated for the top 5000 words. Laplace smoothing parameter of 30 has been used when calculating P(W|C).

# %%
def remove_non_ascii(words):
    """Remove non-ASCII characters from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

def remove_punctuation(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

def replace_numbers(words):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    new_words = []
    for word in words:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return new_words

def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""
    new_words = []
    for word in words:
        if word not in stopwords.words('english'):
            new_words.append(word)
    return new_words

def stem_words(words):
    """Stem words in list of tokenized words"""
    stemmer = LancasterStemmer()
    stems = []
    for word in words:
        stem = stemmer.stem(word)
        stems.append(stem)
    return stems

def lemmatize_verbs(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    return lemmas

def normalize(words):
    words = remove_non_ascii(words)
    words = to_lowercase(words)
    words = remove_punctuation(words)
    words = replace_numbers(words)
    words = remove_stopwords(words)
    return words

# %%
# Dictionary to hold vectorizer objects
class_words_preprocessed = []
# Dictionary to hold Document term matrix for each class.
# The document term matrix is converted to a Pandas DataFrame
class_dict = {}
for label in list(train['label'].unique()):
    for filename in train.loc[train['label'] == label]['filename']:
        with open(filename,'r',errors='ignore') as filein:
            data = filein.read()
        # Preprocessing using nltk packages
        words = nltk.word_tokenize(data)
        words = normalize(words)
        class_words_preprocessed.append(words)

# %%
# Dictionary to hold vectorizer objects
vect_dict = {}
# Dictionary to hold Document term matrix for each class.
# The document term matrix is converted to a Pandas DataFrame
class_dict = {}
for label in list(train['label'].unique()):
    vect_dict[label] = CountVectorizer(input='filename',analyzer='word',stop_words='english',decode_error='ignore')
    class_dict[label] = pd.DataFrame(vect_dict[label].fit_transform(list(train.loc[train['label'] == label]['filename'])).todense().T)
    class_dict[label]['count_docs'] = class_dict[label].sum(axis=1)
    class_dict[label]['word'] = vect_dict[label].get_feature_names()
    class_dict[label] = class_dict[label].sort_values(by='count_docs',ascending=False).iloc[:5000,:]
    tot_freq = class_dict[label]['count_docs'].sum()
    class_dict[label]['p(w|c)'] =  (class_dict[label]['count_docs'] + 30) / (tot_freq + (5000 * 30))

# %% [markdown]
# Considering the top 25 most frequent words for all labels, are there any words which occur in all the documents?

# %%
top25_list = []
for label in list(train['label'].unique()):
    top25_list.append(class_dict[label].iloc[:25,:]['word'])
intersect = set(top25_list[0])
for list_ in top25_list[1:]:
    intersect.intersection_update(list_)
print(intersect)
# Out:
# {'cantaloupe', 'cmu', 'srv', 'date', 'cs', 'message', 'edu', 'lines', 'subject', 'net', 'com'}

# %% [markdown]
# Removing these words from each dictionary and recalculating probabilities

# %%
for label in list(train['label'].unique()):
    class_dict[label] = class_dict[label].loc[~ class_dict[label]['word'].isin(list(intersect))]
for label in list(train['label'].unique()):
    tot_freq = class_dict[label]['count_docs'].sum()
    class_dict[label]['p(w|c)'] =  (class_dict[label]['count_docs'] + 30) / (tot_freq + (5000 * 30))

# %%
# Final Word Dictionary for each class
for label in list(train['label'].unique()):
    class_dict[label] = pd.Series(class_dict[label]['p(w|c)'].values,index=class_dict[label]['word']).to_dict()

# %%
#class_dict['comp.graphics'].shape

# %% [markdown]
# The words **cmu, edu,com,cs** can be removed for better results

# %% [markdown]
# ## Calculating Class Priors

# %%
class_priors_dict = {}
total_freq = 0
for label in list(files_df['label'].unique()):
    class_priors_dict[label] = files_df.loc[files_df['label'] == label].shape[0]
    total_freq += class_priors_dict[label]
for label in list(files_df['label'].unique()):
    class_priors_dict[label] = np.round(class_priors_dict[label] / total_freq, 4)

# %%
class_priors_dict
# Out:
# {'comp.graphics': 0.050000000000000003,
#  'talk.religion.misc': 0.050000000000000003,
#  'rec.sport.baseball': 0.050000000000000003,
#  'comp.sys.ibm.pc.hardware': 0.050000000000000003,
#  'rec.motorcycles': 0.050000000000000003,
#  'talk.politics.guns': 0.050000000000000003,
#  'misc.forsale': 0.050000000000000003,
#  'alt.atheism': 0.050000000000000003,
#  'talk.politics.misc': 0.050000000000000003,
#  'talk.politics.mideast': 0.050000000000000003,
#  'rec.autos': 0.050000000000000003,
#  'comp.windows.x': 0.050000000000000003,
#  'sci.crypt': 0.050000000000000003,
#  'sci.electronics': 0.050000000000000003,
#  'soc.religion.christian': 0.0499,
#  'rec.sport.hockey': 0.050000000000000003,
#  'comp.os.ms-windows.misc': 0.050000000000000003,
#  'sci.space': 0.050000000000000003,
#  'comp.sys.mac.hardware': 0.050000000000000003,
#  'sci.med': 0.050000000000000003}

# %% [markdown]
# ### Calculating Training Accuracy

# %%
train_predicted = pd.DataFrame(columns=['predicted','max_class_posterior_prob'])
for train_doc in list(train['filename']):
    vect_train = CountVectorizer(input='filename',analyzer='word',stop_words='english',decode_error='ignore')
    train_docterm = pd.DataFrame(vect_train.fit_transform([train_doc]).todense().T)
    #print(vect_train.get_feature_names())
    log_posterior_dict = class_priors_dict
    log_posterior_dict = dict([(k,math.log(v)) for (k,v) in log_posterior_dict.items()])
    for word in vect_train.get_feature_names():
        for k,v in log_posterior_dict.items():
            try:
                log_posterior_dict[k] = log_posterior_dict[k] + math.log(class_dict[k][word])
            except:
                pass
    log_posterior_dict = dict([(k,np.exp(v)) for (k,v) in log_posterior_dict.items()])
    train_predicted = train_predicted.append({'predicted':max(log_posterior_dict, key=log_posterior_dict.get),'max_class_posterior_prob':max(log_posterior_dict.values())},ignore_index=True)
train_predicted['actual'] = train['label']   
print('Training Accuracy : {}'.format(np.round(train_predicted.loc[train_predicted['predicted'] == train_predicted['actual']].shape[0]/train_predicted.shape[0],4)))
# Out:
# Training Accuracy : 0.0047

# %% [markdown]
# ### Calculating Test Accuracy

# %%
test_predicted = pd.DataFrame(columns=['predicted','max_class_posterior_prob'])
for test_doc in list(test['filename']):
    vect_test = CountVectorizer(input='filename',analyzer='word',stop_words='english',decode_error='ignore')
    test_docterm = pd.DataFrame(vect_test.fit_transform([test_doc]).todense().T)
    #print(vect_train.get_feature_names())
    log_posterior_dict = class_priors_dict
    log_posterior_dict = dict([(k,math.log(v)) for (k,v) in log_posterior_dict.items()])
    for word in vect_test.get_feature_names():
        for k,v in log_posterior_dict.items():
            try:
                log_posterior_dict[k] = log_posterior_dict[k] + math.log(class_dict[k][word])
            except:
                pass
    log_posterior_dict = dict([(k,np.exp(v)) for (k,v) in log_posterior_dict.items()])
    test_predicted = test_predicted.append({'predicted':max(log_posterior_dict, key=log_posterior_dict.get),'max_class_posterior_prob':max(log_posterior_dict.values())},ignore_index=True)
test_predicted['actual'] = test['label']   
print('Testing Accuracy : {}'.format(np.round(test_predicted.loc[test_predicted['predicted'] == test_predicted['actual']].shape[0]/test_predicted.shape[0],4)))
# Out:
# Testing Accuracy : 0.0068

# %% [markdown]
# It is seen that the training and test accuracy is very low, at 1.75% and 2.28% respectively.

# %% [markdown]
# ## Creating dictionary of 10,000 most frequent words in each class

# %%
# Dictionary to hold vectorizer objects
vect_dict = {}
# Dictionary to hold Document term matrix for each class.
# The document term matrix is converted to a Pandas DataFrame
class_dict = {}
for label in list(train['label'].unique()):
    vect_dict[label] = CountVectorizer(input='filename',analyzer='word',stop_words='english',decode_error='ignore')
    class_dict[label] = pd.DataFrame(vect_dict[label].fit_transform(list(train.loc[train['label'] == label]['filename'])).todense().T)
    class_dict[label]['count_docs'] = class_dict[label].sum(axis=1)
    class_dict[label]['word'] = vect_dict[label].get_feature_names()
    class_dict[label] = class_dict[label].sort_values(by='count_docs',ascending=False).iloc[:10000,:]
    tot_freq = class_dict[label]['count_docs'].sum()
    class_dict[label]['p(w|c)'] =  (class_dict[label]['count_docs'] + 30) / (tot_freq + (10000 * 30))

# %%
# Final Word Dictionary for each class
for label in list(train['label'].unique()):
    class_dict[label] = pd.Series(class_dict[label]['p(w|c)'].values,index=class_dict[label]['word']).to_dict()

# %% [markdown]
# ### Calculating Training Accuracy

# %%
train_predicted = pd.DataFrame(columns=['predicted','max_class_posterior_prob'])
for train_doc in list(train['filename']):
    vect_train = CountVectorizer(input='filename',analyzer='word',stop_words='english',decode_error='ignore')
    train_docterm = pd.DataFrame(vect_train.fit_transform([train_doc]).todense().T)
    #print(vect_train.get_feature_names())
    log_posterior_dict = class_priors_dict
    log_posterior_dict = dict([(k,math.log(v)) for (k,v) in log_posterior_dict.items()])
    for word in vect_train.get_feature_names():
        for k,v in log_posterior_dict.items():
            try:
                log_posterior_dict[k] = log_posterior_dict[k] + math.log(class_dict[k][word])
            except:
                pass
    log_posterior_dict = dict([(k,np.exp(v)) for (k,v) in log_posterior_dict.items()])
    train_predicted = train_predicted.append({'predicted':max(log_posterior_dict, key=log_posterior_dict.get),'max_class_posterior_prob':max(log_posterior_dict.values())},ignore_index=True)
train_predicted['actual'] = train['label']   
print('Training Accuracy : {}'.format(np.round(train_predicted.loc[train_predicted['predicted'] == train_predicted['actual']].shape[0]/train_predicted.shape[0],4)))
# Out:
# Training Accuracy : 0.0119

# %% [markdown]
# ### Calculating Test Accuracy

# %%
test_predicted = pd.DataFrame(columns=['predicted','max_class_posterior_prob'])
for test_doc in list(test['filename']):
    vect_test = CountVectorizer(input='filename',analyzer='word',stop_words='english',decode_error='ignore')
    test_docterm = pd.DataFrame(vect_test.fit_transform([test_doc]).todense().T)
    #print(vect_train.get_feature_names())
    log_posterior_dict = class_priors_dict
    log_posterior_dict = dict([(k,math.log(v)) for (k,v) in log_posterior_dict.items()])
    for word in vect_test.get_feature_names():
        for k,v in log_posterior_dict.items():
            try:
                log_posterior_dict[k] = log_posterior_dict[k] + math.log(class_dict[k][word])
            except:
                pass
    log_posterior_dict = dict([(k,np.exp(v)) for (k,v) in log_posterior_dict.items()])
    test_predicted = test_predicted.append({'predicted':max(log_posterior_dict, key=log_posterior_dict.get),'max_class_posterior_prob':max(log_posterior_dict.values())},ignore_index=True)
test_predicted['actual'] = test['label']   
print('Testing Accuracy : {}'.format(np.round(test_predicted.loc[test_predicted['predicted'] == test_predicted['actual']].shape[0]/test_predicted.shape[0],4)))
# Out:
# Testing Accuracy : 0.013

# %% [markdown]
# **It is seen that increasing the dictionary to 10,000 increases the training and test accuracies to 2.9% and 3.6%. This can be improved further.**

# %%
train_predicted = pd.DataFrame(columns=['predicted','max_class_posterior_prob'])
for train_doc in list(train.iloc[:1,:]['filename']):
    vect_train = CountVectorizer(input='filename',analyzer='word',stop_words='english',decode_error='ignore')
    train_docterm = pd.DataFrame(vect_train.fit_transform([train_doc]).todense().T)
    #print(vect_train.get_feature_names())
    log_posterior_dict = class_priors_dict
    log_posterior_dict = dict([(k,math.log(v)) for (k,v) in log_posterior_dict.items()])
    for word in vect_train.get_feature_names():
        for k,v in log_posterior_dict.items():
            try:
                log_posterior_dict[k] = log_posterior_dict[k] + math.log(class_dict[k][word])
                print('Word {0} matched from {1} class'.format(word,k))
            except:
                pass
    log_posterior_dict = dict([(k,np.exp(v)) for (k,v) in log_posterior_dict.items()])
    train_predicted = train_predicted.append({'predicted':max(log_posterior_dict, key=log_posterior_dict.get),'max_class_posterior_prob':max(log_posterior_dict.values())},ignore_index=True)
train_predicted['actual'] = train['label']   
print('Training Accuracy : {}'.format(np.round(train_predicted.loc[train_predicted['predicted'] == train_predicted['actual']].shape[0]/train_predicted.shape[0],4)))
# Out:
# Word 02 matched from comp.graphics class
# Word 02 matched from talk.religion.misc class
# Word 02 matched from rec.sport.baseball class
# Word 02 matched from comp.sys.ibm.pc.hardware class
# Word 02 matched from rec.motorcycles class
# Word 02 matched from talk.politics.guns class
# Word 02 matched from misc.forsale class
# Word 02 matched from alt.atheism class
# Word 02 matched from talk.politics.misc class
# Word 02 matched from talk.politics.mideast class
# Word 02 matched from rec.autos class
# Word 02 matched from comp.windows.x class
# Word 02 matched from sci.crypt class
# Word 02 matched from sci.electronics class
# Word 02 matched from soc.religion.christian class
# Word 02 matched from rec.sport.hockey class
# Word 02 matched from comp.os.ms-windows.misc class
# Word 02 matched from sci.space class
# Word 02 matched from comp.sys.mac.hardware class
# Word 02 matched from sci.med class
# Word 07 matched from comp.graphics class
# Word 07 matched from talk.religion.misc class
# Word 07 matched from rec.sport.baseball class
# Word 07 matched from comp.sys.ibm.pc.hardware class
# Word 07 matched from rec.motorcycles class
# Word 07 matched from talk.politics.guns class
# Word 07 matched from misc.forsale class
# Word 07 matched from alt.atheism class
# Word 07 matched from talk.politics.misc class
# Word 07 matched from talk.politics.mideast class
# Word 07 matched from rec.autos class
# Word 07 matched from comp.windows.x class
# Word 07 matched from sci.crypt class
# Word 07 matched from sci.electronics class
# Word 07 matched from soc.religion.christian class
# Word 07 matched from rec.sport.hockey class
# Word 07 matched from comp.os.ms-windows.misc class
# Word 07 matched from sci.space class
# Word 07 matched from comp.sys.mac.hardware class
# Word 07 matched from sci.med class
# Word 13 matched from comp.graphics class
# Word 13 matched from talk.religion.misc class
# Word 13 matched from rec.sport.baseball class
# Word 13 matched from comp.sys.ibm.pc.hardware class
# Word 13 matched from rec.motorcycles class
# Word 13 matched from talk.politics.guns class
# Word 13 matched from misc.forsale class
# Word 13 matched from alt.atheism class
# Word 13 matched from talk.politics.misc class
# Word 13 matched from talk.politics.mideast class
# Word 13 matched from rec.autos class
# Word 13 matched from comp.windows.x class
# Word 13 matched from sci.crypt class
# Word 13 matched from sci.electronics class
# Word 13 matched from soc.religion.christian class
# Word 13 matched from rec.sport.hockey class
# Word 13 matched from comp.os.ms-windows.misc class
# Word 13 matched from sci.space class
# Word 13 matched from comp.sys.mac.hardware class
# Word 13 matched from sci.med class
# Word 18494 matched from comp.graphics class
# Word 30 matched from comp.graphics class
# Word 30 matched from talk.religion.misc class
# Word 30 matched from rec.sport.baseball class
# Word 30 matched from comp.sys.ibm.pc.hardware class
# Word 30 matched from rec.motorcycles class
# Word 30 matched from talk.politics.guns class
# Word 30 matched from misc.forsale class
# Word 30 matched from alt.atheism class
# Word 30 matched from talk.politics.misc class
# Word 30 matched from talk.politics.mideast class
# Word 30 matched from rec.autos class
# Word 30 matched from comp.windows.x class
# Word 30 matched from sci.crypt class
# Word 30 matched from sci.electronics class
# Word 30 matched from soc.religion.christian class
# Word 30 matched from rec.sport.hockey class
# Word 30 matched from comp.os.ms-windows.misc class
# Word 30 matched from sci.space class
# Word 30 matched from comp.sys.mac.hardware class
# Word 30 matched from sci.med class
# Word 93 matched from comp.graphics class
# Word 93 matched from talk.religion.misc class
# Word 93 matched from rec.sport.baseball class
# Word 93 matched from comp.sys.ibm.pc.hardware class
# Word 93 matched from rec.motorcycles class
# Word 93 matched from talk.politics.guns class
# Word 93 matched from misc.forsale class
# Word 93 matched from alt.atheism class
# Word 93 matched from talk.politics.misc class
# Word 93 matched from talk.politics.mideast class
# Word 93 matched from rec.autos class
# Word 93 matched from comp.windows.x class
# Word 93 matched from sci.crypt class
# Word 93 matched from sci.electronics class
# Word 93 matched from soc.religion.christian class
# Word 93 matched from rec.sport.hockey class
# Word 93 matched from comp.os.ms-windows.misc class
# Word 93 matched from sci.space class
# Word 93 matched from comp.sys.mac.hardware class
# Word 93 matched from sci.med class
# Word address matched from comp.graphics class
# Word address matched from talk.religion.misc class
# Word address matched from rec.sport.baseball class
# Word address matched from comp.sys.ibm.pc.hardware class
# Word address matched from rec.motorcycles class
# Word address matched from talk.politics.guns class
# Word address matched from misc.forsale class
# Word address matched from alt.atheism class
# Word address matched from talk.politics.misc class
# Word address matched from talk.politics.mideast class
# Word address matched from rec.autos class
# Word address matched from comp.windows.x class
# Word address matched from sci.crypt class
# Word address matched from sci.electronics class
# Word address matched from soc.religion.christian class
# Word address matched from rec.sport.hockey class
# Word address matched from comp.os.ms-windows.misc class
# Word address matched from sci.space class
# Word address matched from comp.sys.mac.hardware class
# Word address matched from sci.med class
# Word advance matched from comp.graphics class
# Word advance matched from talk.religion.misc class
# Word advance matched from rec.sport.baseball class
# Word advance matched from comp.sys.ibm.pc.hardware class
# Word advance matched from rec.motorcycles class
# Word advance matched from talk.politics.guns class
# Word advance matched from misc.forsale class
# Word advance matched from alt.atheism class
# Word advance matched from talk.politics.misc class
# Word advance matched from talk.politics.mideast class
# Word advance matched from rec.autos class
# Word advance matched from comp.windows.x class
# Word advance matched from sci.crypt class
# Word advance matched from sci.electronics class
# Word advance matched from soc.religion.christian class
# Word advance matched from rec.sport.hockey class
# Word advance matched from comp.os.ms-windows.misc class
# Word advance matched from sci.space class
# Word advance matched from comp.sys.mac.hardware class
# Word advance matched from sci.med class
# Word ans matched from comp.graphics class
# Word ans matched from talk.religion.misc class
# Word ans matched from rec.sport.baseball class
# Word ans matched from comp.sys.ibm.pc.hardware class
# Word ans matched from rec.motorcycles class
# Word ans matched from talk.politics.guns class
# Word ans matched from misc.forsale class
# Word ans matched from alt.atheism class
# Word ans matched from talk.politics.misc class
# Word ans matched from talk.politics.mideast class
# Word ans matched from rec.autos class
# Word ans matched from comp.windows.x class
# Word ans matched from sci.crypt class
# Word ans matched from sci.electronics class
# Word ans matched from soc.religion.christian class
# Word ans matched from rec.sport.hockey class
# Word ans matched from comp.os.ms-windows.misc class
# Word ans matched from sci.space class
# Word ans matched from comp.sys.mac.hardware class
# Word ans matched from sci.med class
# Word apr matched from comp.graphics class
# Word apr matched from talk.religion.misc class
# Word apr matched from rec.sport.baseball class
# Word apr matched from comp.sys.ibm.pc.hardware class
# Word apr matched from rec.motorcycles class
# Word apr matched from talk.politics.guns class
# Word apr matched from misc.forsale class
# Word apr matched from alt.atheism class
# Word apr matched from talk.politics.misc class
# Word apr matched from talk.politics.mideast class
# Word apr matched from rec.autos class
# Word apr matched from comp.windows.x class
# Word apr matched from sci.crypt class
# Word apr matched from sci.electronics class
# Word apr matched from soc.religion.christian class
# Word apr matched from rec.sport.hockey class
# Word apr matched from comp.os.ms-windows.misc class
# Word apr matched from sci.space class
# Word apr matched from comp.sys.mac.hardware class
# Word apr matched from sci.med class
# Word au matched from comp.graphics class
# Word au matched from talk.religion.misc class
# Word au matched from rec.sport.baseball class
# Word au matched from comp.sys.ibm.pc.hardware class
# Word au matched from rec.motorcycles class
# Word au matched from talk.politics.guns class
# Word au matched from alt.atheism class
# Word au matched from talk.politics.mideast class
# Word au matched from rec.autos class
# Word au matched from comp.windows.x class
# Word au matched from sci.crypt class
# Word au matched from sci.electronics class
# Word au matched from soc.religion.christian class
# Word au matched from comp.os.ms-windows.misc class
# Word au matched from sci.space class
# Word au matched from comp.sys.mac.hardware class
# Word au matched from sci.med class
# Word australia matched from comp.graphics class
# Word australia matched from talk.religion.misc class
# Word australia matched from comp.sys.ibm.pc.hardware class
# Word australia matched from talk.politics.guns class
# Word australia matched from alt.atheism class
# Word australia matched from talk.politics.misc class
# Word australia matched from rec.autos class
# Word australia matched from comp.windows.x class
# Word australia matched from sci.crypt class
# Word australia matched from sci.electronics class
# Word australia matched from soc.religion.christian class
# Word australia matched from comp.os.ms-windows.misc class
# Word australia matched from sci.space class
# Word australia matched from comp.sys.mac.hardware class
# Word australia matched from sci.med class
# Word believe matched from comp.graphics class
# Word believe matched from talk.religion.misc class
# Word believe matched from rec.sport.baseball class
# Word believe matched from comp.sys.ibm.pc.hardware class
# Word believe matched from rec.motorcycles class
# Word believe matched from talk.politics.guns class
# Word believe matched from misc.forsale class
# Word believe matched from alt.atheism class
# Word believe matched from talk.politics.misc class
# Word believe matched from talk.politics.mideast class
# Word believe matched from rec.autos class
# Word believe matched from comp.windows.x class
# Word believe matched from sci.crypt class
# Word believe matched from sci.electronics class
# Word believe matched from soc.religion.christian class
# Word believe matched from rec.sport.hockey class
# Word believe matched from comp.os.ms-windows.misc class
# Word believe matched from sci.space class
# Word believe matched from comp.sys.mac.hardware class
# Word believe matched from sci.med class
# Word busy matched from talk.religion.misc class
# Word busy matched from comp.sys.ibm.pc.hardware class
# Word busy matched from rec.motorcycles class
# Word busy matched from alt.atheism class
# Word busy matched from talk.politics.misc class
# Word busy matched from talk.politics.mideast class
# Word busy matched from rec.autos class
# Word busy matched from comp.windows.x class
# Word busy matched from sci.crypt class
# Word busy matched from sci.electronics class
# Word busy matched from soc.religion.christian class
# Word busy matched from rec.sport.hockey class
# Word busy matched from sci.space class
# Word busy matched from sci.med class
# Word campus matched from comp.graphics class
# Word campus matched from talk.religion.misc class
# Word campus matched from comp.sys.ibm.pc.hardware class
# Word campus matched from rec.motorcycles class
# Word campus matched from talk.politics.guns class
# Word campus matched from misc.forsale class
# Word campus matched from alt.atheism class
# Word campus matched from talk.politics.misc class
# Word campus matched from talk.politics.mideast class
# Word campus matched from rec.autos class
# Word campus matched from comp.windows.x class
# Word campus matched from sci.crypt class
# Word campus matched from sci.electronics class
# Word campus matched from soc.religion.christian class
# Word campus matched from rec.sport.hockey class
# Word campus matched from comp.os.ms-windows.misc class
# Word campus matched from sci.space class
# Word campus matched from comp.sys.mac.hardware class
# Word campus matched from sci.med class
# Word cantaloupe matched from comp.graphics class
# Word cantaloupe matched from talk.religion.misc class
# Word cantaloupe matched from rec.sport.baseball class
# Word cantaloupe matched from comp.sys.ibm.pc.hardware class
# Word cantaloupe matched from rec.motorcycles class
# Word cantaloupe matched from talk.politics.guns class
# Word cantaloupe matched from misc.forsale class
# Word cantaloupe matched from alt.atheism class
# Word cantaloupe matched from talk.politics.misc class
# Word cantaloupe matched from talk.politics.mideast class
# Word cantaloupe matched from rec.autos class
# Word cantaloupe matched from comp.windows.x class
# Word cantaloupe matched from sci.crypt class
# Word cantaloupe matched from sci.electronics class
# Word cantaloupe matched from soc.religion.christian class
# Word cantaloupe matched from rec.sport.hockey class
# Word cantaloupe matched from comp.os.ms-windows.misc class
# Word cantaloupe matched from sci.space class
# Word cantaloupe matched from comp.sys.mac.hardware class
# Word cantaloupe matched from sci.med class
# Word clever matched from comp.graphics class
# Word clever matched from talk.religion.misc class
# Word clever matched from talk.politics.guns class
# Word clever matched from alt.atheism class
# Word clever matched from rec.autos class
# Word clever matched from sci.crypt class
# Word clever matched from sci.electronics class
# Word clever matched from soc.religion.christian class
# Word clever matched from comp.os.ms-windows.misc class
# Word clever matched from sci.space class
# Word clever matched from comp.sys.mac.hardware class
# Word cmu matched from comp.graphics class
# Word cmu matched from talk.religion.misc class
# Word cmu matched from rec.sport.baseball class
# Word cmu matched from comp.sys.ibm.pc.hardware class
# Word cmu matched from rec.motorcycles class
# Word cmu matched from talk.politics.guns class
# Word cmu matched from misc.forsale class
# Word cmu matched from alt.atheism class
# Word cmu matched from talk.politics.misc class
# Word cmu matched from talk.politics.mideast class
# Word cmu matched from rec.autos class
# Word cmu matched from comp.windows.x class
# Word cmu matched from sci.crypt class
# Word cmu matched from sci.electronics class
# Word cmu matched from soc.religion.christian class
# Word cmu matched from rec.sport.hockey class
# Word cmu matched from comp.os.ms-windows.misc class
# Word cmu matched from sci.space class
# Word cmu matched from comp.sys.mac.hardware class
# Word cmu matched from sci.med class
# Word code matched from comp.graphics class
# Word code matched from talk.religion.misc class
# Word code matched from comp.sys.ibm.pc.hardware class
# Word code matched from rec.motorcycles class
# Word code matched from talk.politics.guns class
# Word code matched from misc.forsale class
# Word code matched from alt.atheism class
# Word code matched from talk.politics.misc class
# Word code matched from talk.politics.mideast class
# Word code matched from rec.autos class
# Word code matched from comp.windows.x class
# Word code matched from sci.crypt class
# Word code matched from sci.electronics class
# Word code matched from soc.religion.christian class
# Word code matched from comp.os.ms-windows.misc class
# Word code matched from sci.space class
# Word code matched from comp.sys.mac.hardware class
# Word code matched from sci.med class
# Word com matched from comp.graphics class
# Word com matched from talk.religion.misc class
# Word com matched from rec.sport.baseball class
# Word com matched from comp.sys.ibm.pc.hardware class
# Word com matched from rec.motorcycles class
# Word com matched from talk.politics.guns class
# Word com matched from misc.forsale class
# Word com matched from alt.atheism class
# Word com matched from talk.politics.misc class
# Word com matched from talk.politics.mideast class
# Word com matched from rec.autos class
# Word com matched from comp.windows.x class
# Word com matched from sci.crypt class
# Word com matched from sci.electronics class
# Word com matched from soc.religion.christian class
# Word com matched from rec.sport.hockey class
# Word com matched from comp.os.ms-windows.misc class
# Word com matched from sci.space class
# Word com matched from comp.sys.mac.hardware class
# Word com matched from sci.med class
# Word comp matched from comp.graphics class
# Word comp matched from rec.sport.baseball class
# Word comp matched from comp.sys.ibm.pc.hardware class
# Word comp matched from rec.motorcycles class
# Word comp matched from talk.politics.guns class
# Word comp matched from misc.forsale class
# Word comp matched from talk.politics.misc class
# Word comp matched from talk.politics.mideast class
# Word comp matched from rec.autos class
# Word comp matched from comp.windows.x class
# Word comp matched from sci.crypt class
# Word comp matched from sci.electronics class
# Word comp matched from soc.religion.christian class
# Word comp matched from comp.os.ms-windows.misc class
# Word comp matched from sci.space class
# Word comp matched from comp.sys.mac.hardware class
# Word comp matched from sci.med class
# Word compatible matched from comp.graphics class
# Word compatible matched from comp.sys.ibm.pc.hardware class
# Word compatible matched from misc.forsale class
# Word compatible matched from alt.atheism class
# Word compatible matched from talk.politics.mideast class
# Word compatible matched from rec.autos class
# Word compatible matched from comp.windows.x class
# Word compatible matched from sci.crypt class
# Word compatible matched from sci.electronics class
# Word compatible matched from soc.religion.christian class
# Word compatible matched from comp.os.ms-windows.misc class
# Word compatible matched from comp.sys.mac.hardware class
# Word compatible matched from sci.med class
# Word computer matched from comp.graphics class
# Word computer matched from talk.religion.misc class
# Word computer matched from rec.sport.baseball class
# Word computer matched from comp.sys.ibm.pc.hardware class
# Word computer matched from rec.motorcycles class
# Word computer matched from talk.politics.guns class
# Word computer matched from misc.forsale class
# Word computer matched from alt.atheism class
# Word computer matched from talk.politics.misc class
# Word computer matched from talk.politics.mideast class
# Word computer matched from rec.autos class
# Word computer matched from comp.windows.x class
# Word computer matched from sci.crypt class
# Word computer matched from sci.electronics class
# Word computer matched from soc.religion.christian class
# Word computer matched from rec.sport.hockey class
# Word computer matched from comp.os.ms-windows.misc class
# Word computer matched from sci.space class
# Word computer matched from comp.sys.mac.hardware class
# Word computer matched from sci.med class
# Word cs matched from comp.graphics class
# Word cs matched from talk.religion.misc class
# Word cs matched from rec.sport.baseball class
# Word cs matched from comp.sys.ibm.pc.hardware class
# Word cs matched from rec.motorcycles class
# Word cs matched from talk.politics.guns class
# Word cs matched from misc.forsale class
# Word cs matched from alt.atheism class
# Word cs matched from talk.politics.misc class
# Word cs matched from talk.politics.mideast class
# Word cs matched from rec.autos class
# Word cs matched from comp.windows.x class
# Word cs matched from sci.crypt class
# Word cs matched from sci.electronics class
# Word cs matched from soc.religion.christian class
# Word cs matched from rec.sport.hockey class
# Word cs matched from comp.os.ms-windows.misc class
# Word cs matched from sci.space class
# Word cs matched from comp.sys.mac.hardware class
# Word cs matched from sci.med class
# Word das matched from comp.graphics class
# Word das matched from talk.religion.misc class
# Word das matched from rec.sport.baseball class
# Word das matched from comp.sys.ibm.pc.hardware class
# Word das matched from rec.motorcycles class
# Word das matched from talk.politics.guns class
# Word das matched from misc.forsale class
# Word das matched from alt.atheism class
# Word das matched from talk.politics.misc class
# Word das matched from talk.politics.mideast class
# Word das matched from rec.autos class
# Word das matched from comp.windows.x class
# Word das matched from sci.crypt class
# Word das matched from sci.electronics class
# Word das matched from soc.religion.christian class
# Word das matched from rec.sport.hockey class
# Word das matched from comp.os.ms-windows.misc class
# Word das matched from sci.space class
# Word das matched from comp.sys.mac.hardware class
# Word das matched from sci.med class
# Word date matched from comp.graphics class
# Word date matched from talk.religion.misc class
# Word date matched from rec.sport.baseball class
# Word date matched from comp.sys.ibm.pc.hardware class
# Word date matched from rec.motorcycles class
# Word date matched from talk.politics.guns class
# Word date matched from misc.forsale class
# Word date matched from alt.atheism class
# Word date matched from talk.politics.misc class
# Word date matched from talk.politics.mideast class
# Word date matched from rec.autos class
# Word date matched from comp.windows.x class
# Word date matched from sci.crypt class
# Word date matched from sci.electronics class
# Word date matched from soc.religion.christian class
# Word date matched from rec.sport.hockey class
# Word date matched from comp.os.ms-windows.misc class
# Word date matched from sci.space class
# Word date matched from comp.sys.mac.hardware class
# Word date matched from sci.med class
# Word edu matched from comp.graphics class
# Word edu matched from talk.religion.misc class
# Word edu matched from rec.sport.baseball class
# Word edu matched from comp.sys.ibm.pc.hardware class
# Word edu matched from rec.motorcycles class
# Word edu matched from talk.politics.guns class
# Word edu matched from misc.forsale class
# Word edu matched from alt.atheism class
# Word edu matched from talk.politics.misc class
# Word edu matched from talk.politics.mideast class
# Word edu matched from rec.autos class
# Word edu matched from comp.windows.x class
# Word edu matched from sci.crypt class
# Word edu matched from sci.electronics class
# Word edu matched from soc.religion.christian class
# Word edu matched from rec.sport.hockey class
# Word edu matched from comp.os.ms-windows.misc class
# Word edu matched from sci.space class
# Word edu matched from comp.sys.mac.hardware class
# Word edu matched from sci.med class
# Word gmt matched from comp.graphics class
# Word gmt matched from talk.religion.misc class
# Word gmt matched from rec.sport.baseball class
# Word gmt matched from comp.sys.ibm.pc.hardware class
# Word gmt matched from rec.motorcycles class
# Word gmt matched from talk.politics.guns class
# Word gmt matched from misc.forsale class
# Word gmt matched from alt.atheism class
# Word gmt matched from talk.politics.misc class
# Word gmt matched from talk.politics.mideast class
# Word gmt matched from rec.autos class
# Word gmt matched from comp.windows.x class
# Word gmt matched from sci.crypt class
# Word gmt matched from sci.electronics class
# Word gmt matched from soc.religion.christian class
# Word gmt matched from rec.sport.hockey class
# Word gmt matched from comp.os.ms-windows.misc class
# Word gmt matched from sci.space class
# Word gmt matched from comp.sys.mac.hardware class
# Word gmt matched from sci.med class
# Word goanna matched from comp.graphics class
# Word goanna matched from comp.sys.ibm.pc.hardware class
# Word goanna matched from sci.electronics class
# Word graphics matched from comp.graphics class
# Word graphics matched from rec.sport.baseball class
# Word graphics matched from comp.sys.ibm.pc.hardware class
# Word graphics matched from rec.motorcycles class
# Word graphics matched from talk.politics.guns class
# Word graphics matched from misc.forsale class
# Word graphics matched from talk.politics.misc class
# Word graphics matched from rec.autos class
# Word graphics matched from comp.windows.x class
# Word graphics matched from sci.crypt class
# Word graphics matched from sci.electronics class
# Word graphics matched from soc.religion.christian class
# Word graphics matched from rec.sport.hockey class
# Word graphics matched from comp.os.ms-windows.misc class
# Word graphics matched from sci.space class
# Word graphics matched from comp.sys.mac.hardware class
# Word graphics matched from sci.med class
# Word harvard matched from comp.graphics class
# Word harvard matched from talk.religion.misc class
# Word harvard matched from rec.sport.baseball class
# Word harvard matched from comp.sys.ibm.pc.hardware class
# Word harvard matched from rec.motorcycles class
# Word harvard matched from talk.politics.guns class
# Word harvard matched from misc.forsale class
# Word harvard matched from alt.atheism class
# Word harvard matched from talk.politics.misc class
# Word harvard matched from talk.politics.mideast class
# Word harvard matched from rec.autos class
# Word harvard matched from comp.windows.x class
# Word harvard matched from sci.crypt class
# Word harvard matched from sci.electronics class
# Word harvard matched from soc.religion.christian class
# Word harvard matched from rec.sport.hockey class
# Word harvard matched from comp.os.ms-windows.misc class
# Word harvard matched from sci.space class
# Word harvard matched from comp.sys.mac.hardware class
# Word harvard matched from sci.med class
# Word help matched from comp.graphics class
# Word help matched from talk.religion.misc class
# Word help matched from rec.sport.baseball class
# Word help matched from comp.sys.ibm.pc.hardware class
# Word help matched from rec.motorcycles class
# Word help matched from talk.politics.guns class
# Word help matched from misc.forsale class
# Word help matched from alt.atheism class
# Word help matched from talk.politics.misc class
# Word help matched from talk.politics.mideast class
# Word help matched from rec.autos class
# Word help matched from comp.windows.x class
# Word help matched from sci.crypt class
# Word help matched from sci.electronics class
# Word help matched from soc.religion.christian class
# Word help matched from rec.sport.hockey class
# Word help matched from comp.os.ms-windows.misc class
# Word help matched from sci.space class
# Word help matched from comp.sys.mac.hardware class
# Word help matched from sci.med class
# Word hi matched from comp.graphics class
# Word hi matched from rec.sport.baseball class
# Word hi matched from comp.sys.ibm.pc.hardware class
# Word hi matched from rec.motorcycles class
# Word hi matched from talk.politics.guns class
# Word hi matched from misc.forsale class
# Word hi matched from alt.atheism class
# Word hi matched from rec.autos class
# Word hi matched from comp.windows.x class
# Word hi matched from sci.crypt class
# Word hi matched from sci.electronics class
# Word hi matched from soc.religion.christian class
# Word hi matched from rec.sport.hockey class
# Word hi matched from comp.os.ms-windows.misc class
# Word hi matched from sci.space class
# Word hi matched from comp.sys.mac.hardware class
# Word hi matched from sci.med class
# Word home matched from comp.graphics class
# Word home matched from talk.religion.misc class
# Word home matched from rec.sport.baseball class
# Word home matched from comp.sys.ibm.pc.hardware class
# Word home matched from rec.motorcycles class
# Word home matched from talk.politics.guns class
# Word home matched from misc.forsale class
# Word home matched from alt.atheism class
# Word home matched from talk.politics.misc class
# Word home matched from talk.politics.mideast class
# Word home matched from rec.autos class
# Word home matched from comp.windows.x class
# Word home matched from sci.crypt class
# Word home matched from sci.electronics class
# Word home matched from soc.religion.christian class
# Word home matched from rec.sport.hockey class
# Word home matched from comp.os.ms-windows.misc class
# Word home matched from sci.space class
# Word home matched from comp.sys.mac.hardware class
# Word home matched from sci.med class
# Word howland matched from comp.graphics class
# Word howland matched from talk.religion.misc class
# Word howland matched from rec.sport.baseball class
# Word howland matched from comp.sys.ibm.pc.hardware class
# Word howland matched from rec.motorcycles class
# Word howland matched from talk.politics.guns class
# Word howland matched from misc.forsale class
# Word howland matched from alt.atheism class
# Word howland matched from talk.politics.misc class
# Word howland matched from talk.politics.mideast class
# Word howland matched from rec.autos class
# Word howland matched from comp.windows.x class
# Word howland matched from sci.crypt class
# Word howland matched from sci.electronics class
# Word howland matched from soc.religion.christian class
# Word howland matched from rec.sport.hockey class
# Word howland matched from comp.os.ms-windows.misc class
# Word howland matched from sci.space class
# Word howland matched from comp.sys.mac.hardware class
# Word howland matched from sci.med class
# Word hp matched from comp.graphics class
# Word hp matched from talk.religion.misc class
# Word hp matched from rec.sport.baseball class
# Word hp matched from comp.sys.ibm.pc.hardware class
# Word hp matched from rec.motorcycles class
# Word hp matched from talk.politics.guns class
# Word hp matched from misc.forsale class
# Word hp matched from alt.atheism class
# Word hp matched from talk.politics.misc class
# Word hp matched from talk.politics.mideast class
# Word hp matched from rec.autos class
# Word hp matched from comp.windows.x class
# Word hp matched from sci.crypt class
# Word hp matched from sci.electronics class
# Word hp matched from soc.religion.christian class
# Word hp matched from rec.sport.hockey class
# Word hp matched from comp.os.ms-windows.misc class
# Word hp matched from sci.space class
# Word hp matched from comp.sys.mac.hardware class
# Word hp matched from sci.med class
# Word ibm matched from comp.graphics class
# Word ibm matched from talk.religion.misc class
# Word ibm matched from rec.sport.baseball class
# Word ibm matched from comp.sys.ibm.pc.hardware class
# Word ibm matched from rec.motorcycles class
# Word ibm matched from talk.politics.guns class
# Word ibm matched from misc.forsale class
# Word ibm matched from alt.atheism class
# Word ibm matched from talk.politics.misc class
# Word ibm matched from talk.politics.mideast class
# Word ibm matched from rec.autos class
# Word ibm matched from comp.windows.x class
# Word ibm matched from sci.crypt class
# Word ibm matched from sci.electronics class
# Word ibm matched from soc.religion.christian class
# Word ibm matched from rec.sport.hockey class
# Word ibm matched from comp.os.ms-windows.misc class
# Word ibm matched from sci.space class
# Word ibm matched from comp.sys.mac.hardware class
# Word ibm matched from sci.med class
# Word ibmpc matched from comp.graphics class
# Word ibmpc matched from misc.forsale class
# Word ibmpc matched from comp.os.ms-windows.misc class
# Word ibmpc matched from comp.sys.mac.hardware class
# Word id matched from comp.graphics class
# Word id matched from talk.religion.misc class
# Word id matched from rec.sport.baseball class
# Word id matched from comp.sys.ibm.pc.hardware class
# Word id matched from rec.motorcycles class
# Word id matched from talk.politics.guns class
# Word id matched from misc.forsale class
# Word id matched from alt.atheism class
# Word id matched from talk.politics.misc class
# Word id matched from talk.politics.mideast class
# Word id matched from rec.autos class
# Word id matched from comp.windows.x class
# Word id matched from sci.crypt class
# Word id matched from sci.electronics class
# Word id matched from soc.religion.christian class
# Word id matched from rec.sport.hockey class
# Word id matched from comp.os.ms-windows.misc class
# Word id matched from sci.space class
# Word id matched from comp.sys.mac.hardware class
# Word id matched from sci.med class
# Word internet matched from comp.graphics class
# Word internet matched from talk.religion.misc class
# Word internet matched from rec.sport.baseball class
# Word internet matched from comp.sys.ibm.pc.hardware class
# Word internet matched from rec.motorcycles class
# Word internet matched from talk.politics.guns class
# Word internet matched from misc.forsale class
# Word internet matched from alt.atheism class
# Word internet matched from talk.politics.misc class
# Word internet matched from talk.politics.mideast class
# Word internet matched from rec.autos class
# Word internet matched from comp.windows.x class
# Word internet matched from sci.crypt class
# Word internet matched from sci.electronics class
# Word internet matched from soc.religion.christian class
# Word internet matched from rec.sport.hockey class
# Word internet matched from comp.os.ms-windows.misc class
# Word internet matched from sci.space class
# Word internet matched from comp.sys.mac.hardware class
# Word internet matched from sci.med class
# Word like matched from comp.graphics class
# Word like matched from talk.religion.misc class
# Word like matched from rec.sport.baseball class
# Word like matched from comp.sys.ibm.pc.hardware class
# Word like matched from rec.motorcycles class
# Word like matched from talk.politics.guns class
# Word like matched from misc.forsale class
# Word like matched from alt.atheism class
# Word like matched from talk.politics.misc class
# Word like matched from talk.politics.mideast class
# Word like matched from rec.autos class
# Word like matched from comp.windows.x class
# Word like matched from sci.crypt class
# Word like matched from sci.electronics class
# Word like matched from soc.religion.christian class
# Word like matched from rec.sport.hockey class
# Word like matched from comp.os.ms-windows.misc class
# Word like matched from sci.space class
# Word like matched from comp.sys.mac.hardware class
# Word like matched from sci.med class
# Word lines matched from comp.graphics class
# Word lines matched from talk.religion.misc class
# Word lines matched from rec.sport.baseball class
# Word lines matched from comp.sys.ibm.pc.hardware class
# Word lines matched from rec.motorcycles class
# Word lines matched from talk.politics.guns class
# Word lines matched from misc.forsale class
# Word lines matched from alt.atheism class
# Word lines matched from talk.politics.misc class
# Word lines matched from talk.politics.mideast class
# Word lines matched from rec.autos class
# Word lines matched from comp.windows.x class
# Word lines matched from sci.crypt class
# Word lines matched from sci.electronics class
# Word lines matched from soc.religion.christian class
# Word lines matched from rec.sport.hockey class
# Word lines matched from comp.os.ms-windows.misc class
# Word lines matched from sci.space class
# Word lines matched from comp.sys.mac.hardware class
# Word lines matched from sci.med class
# Word looked matched from comp.graphics class
# Word looked matched from talk.religion.misc class
# Word looked matched from rec.sport.baseball class
# Word looked matched from comp.sys.ibm.pc.hardware class
# Word looked matched from rec.motorcycles class
# Word looked matched from talk.politics.guns class
# Word looked matched from misc.forsale class
# Word looked matched from alt.atheism class
# Word looked matched from talk.politics.misc class
# Word looked matched from talk.politics.mideast class
# Word looked matched from rec.autos class
# Word looked matched from comp.windows.x class
# Word looked matched from sci.crypt class
# Word looked matched from sci.electronics class
# Word looked matched from soc.religion.christian class
# Word looked matched from rec.sport.hockey class
# Word looked matched from comp.os.ms-windows.misc class
# Word looked matched from sci.space class
# Word looked matched from comp.sys.mac.hardware class
# Word looked matched from sci.med class
# Word melbourne matched from comp.graphics class
# Word melbourne matched from comp.sys.ibm.pc.hardware class
# Word melbourne matched from rec.motorcycles class
# Word melbourne matched from talk.politics.guns class
# Word melbourne matched from talk.politics.misc class
# Word melbourne matched from comp.windows.x class
# Word melbourne matched from sci.crypt class
# Word melbourne matched from sci.electronics class
# Word melbourne matched from soc.religion.christian class
# Word melbourne matched from comp.os.ms-windows.misc class
# Word melbourne matched from sci.space class
# Word melbourne matched from comp.sys.mac.hardware class
# Word message matched from comp.graphics class
# Word message matched from talk.religion.misc class
# Word message matched from rec.sport.baseball class
# Word message matched from comp.sys.ibm.pc.hardware class
# Word message matched from rec.motorcycles class
# Word message matched from talk.politics.guns class
# Word message matched from misc.forsale class
# Word message matched from alt.atheism class
# Word message matched from talk.politics.misc class
# Word message matched from talk.politics.mideast class
# Word message matched from rec.autos class
# Word message matched from comp.windows.x class
# Word message matched from sci.crypt class
# Word message matched from sci.electronics class
# Word message matched from soc.religion.christian class
# Word message matched from rec.sport.hockey class
# Word message matched from comp.os.ms-windows.misc class
# Word message matched from sci.space class
# Word message matched from comp.sys.mac.hardware class
# Word message matched from sci.med class
# Word mps matched from comp.graphics class
# Word mps matched from talk.religion.misc class
# Word mps matched from rec.sport.baseball class
# Word mps matched from comp.sys.ibm.pc.hardware class
# Word mps matched from rec.motorcycles class
# Word mps matched from talk.politics.guns class
# Word mps matched from misc.forsale class
# Word mps matched from alt.atheism class
# Word mps matched from talk.politics.misc class
# Word mps matched from talk.politics.mideast class
# Word mps matched from rec.autos class
# Word mps matched from comp.windows.x class
# Word mps matched from sci.crypt class
# Word mps matched from sci.electronics class
# Word mps matched from soc.religion.christian class
# Word mps matched from rec.sport.hockey class
# Word mps matched from comp.os.ms-windows.misc class
# Word mps matched from sci.space class
# Word mps matched from comp.sys.mac.hardware class
# Word mps matched from sci.med class
# Word munnari matched from comp.graphics class
# Word munnari matched from talk.religion.misc class
# Word munnari matched from comp.sys.ibm.pc.hardware class
# Word munnari matched from rec.motorcycles class
# Word munnari matched from alt.atheism class
# Word munnari matched from talk.politics.mideast class
# Word munnari matched from rec.autos class
# Word munnari matched from comp.windows.x class
# Word munnari matched from sci.crypt class
# Word munnari matched from sci.electronics class
# Word munnari matched from comp.os.ms-windows.misc class
# Word munnari matched from sci.space class
# Word munnari matched from comp.sys.mac.hardware class
# Word munnari matched from sci.med class
# Word near matched from comp.graphics class
# Word near matched from talk.religion.misc class
# Word near matched from rec.sport.baseball class
# Word near matched from comp.sys.ibm.pc.hardware class
# Word near matched from rec.motorcycles class
# Word near matched from talk.politics.guns class
# Word near matched from misc.forsale class
# Word near matched from alt.atheism class
# Word near matched from talk.politics.misc class
# Word near matched from talk.politics.mideast class
# Word near matched from rec.autos class
# Word near matched from comp.windows.x class
# Word near matched from sci.crypt class
# Word near matched from sci.electronics class
# Word near matched from soc.religion.christian class
# Word near matched from rec.sport.hockey class
# Word near matched from comp.os.ms-windows.misc class
# Word near matched from sci.space class
# Word near matched from comp.sys.mac.hardware class
# Word near matched from sci.med class
# Word net matched from comp.graphics class
# Word net matched from talk.religion.misc class
# Word net matched from rec.sport.baseball class
# Word net matched from comp.sys.ibm.pc.hardware class
# Word net matched from rec.motorcycles class
# Word net matched from talk.politics.guns class
# Word net matched from misc.forsale class
# Word net matched from alt.atheism class
# Word net matched from talk.politics.misc class
# Word net matched from talk.politics.mideast class
# Word net matched from rec.autos class
# Word net matched from comp.windows.x class
# Word net matched from sci.crypt class
# Word net matched from sci.electronics class
# Word net matched from soc.religion.christian class
# Word net matched from rec.sport.hockey class
# Word net matched from comp.os.ms-windows.misc class
# Word net matched from sci.space class
# Word net matched from comp.sys.mac.hardware class
# Word net matched from sci.med class
# Word network matched from comp.graphics class
# Word network matched from talk.religion.misc class
# Word network matched from rec.sport.baseball class
# Word network matched from comp.sys.ibm.pc.hardware class
# Word network matched from rec.motorcycles class
# Word network matched from talk.politics.guns class
# Word network matched from misc.forsale class
# Word network matched from alt.atheism class
# Word network matched from talk.politics.misc class
# Word network matched from talk.politics.mideast class
# Word network matched from rec.autos class
# Word network matched from comp.windows.x class
# Word network matched from sci.crypt class
# Word network matched from sci.electronics class
# Word network matched from soc.religion.christian class
# Word network matched from rec.sport.hockey class
# Word network matched from comp.os.ms-windows.misc class
# Word network matched from sci.space class
# Word network matched from comp.sys.mac.hardware class
# Word network matched from sci.med class
# Word news matched from comp.graphics class
# Word news matched from talk.religion.misc class
# Word news matched from rec.sport.baseball class
# Word news matched from comp.sys.ibm.pc.hardware class
# Word news matched from rec.motorcycles class
# Word news matched from talk.politics.guns class
# Word news matched from misc.forsale class
# Word news matched from alt.atheism class
# Word news matched from talk.politics.misc class
# Word news matched from talk.politics.mideast class
# Word news matched from rec.autos class
# Word news matched from comp.windows.x class
# Word news matched from sci.crypt class
# Word news matched from sci.electronics class
# Word news matched from soc.religion.christian class
# Word news matched from rec.sport.hockey class
# Word news matched from comp.os.ms-windows.misc class
# Word news matched from sci.space class
# Word news matched from comp.sys.mac.hardware class
# Word news matched from sci.med class
# Word newsgroups matched from comp.graphics class
# Word newsgroups matched from talk.religion.misc class
# Word newsgroups matched from rec.sport.baseball class
# Word newsgroups matched from comp.sys.ibm.pc.hardware class
# Word newsgroups matched from rec.motorcycles class
# Word newsgroups matched from talk.politics.guns class
# Word newsgroups matched from misc.forsale class
# Word newsgroups matched from alt.atheism class
# Word newsgroups matched from talk.politics.misc class
# Word newsgroups matched from talk.politics.mideast class
# Word newsgroups matched from rec.autos class
# Word newsgroups matched from comp.windows.x class
# Word newsgroups matched from sci.crypt class
# Word newsgroups matched from sci.electronics class
# Word newsgroups matched from soc.religion.christian class
# Word newsgroups matched from rec.sport.hockey class
# Word newsgroups matched from comp.os.ms-windows.misc class
# Word newsgroups matched from sci.space class
# Word newsgroups matched from comp.sys.mac.hardware class
# Word newsgroups matched from sci.med class
# Word noc matched from comp.graphics class
# Word noc matched from talk.religion.misc class
# Word noc matched from rec.sport.baseball class
# Word noc matched from comp.sys.ibm.pc.hardware class
# Word noc matched from rec.motorcycles class
# Word noc matched from talk.politics.guns class
# Word noc matched from misc.forsale class
# Word noc matched from alt.atheism class
# Word noc matched from talk.politics.misc class
# Word noc matched from talk.politics.mideast class
# Word noc matched from rec.autos class
# Word noc matched from comp.windows.x class
# Word noc matched from sci.crypt class
# Word noc matched from sci.electronics class
# Word noc matched from soc.religion.christian class
# Word noc matched from rec.sport.hockey class
# Word noc matched from comp.os.ms-windows.misc class
# Word noc matched from sci.space class
# Word noc matched from comp.sys.mac.hardware class
# Word noc matched from sci.med class
# Word ohio matched from comp.graphics class
# Word ohio matched from talk.religion.misc class
# Word ohio matched from rec.sport.baseball class
# Word ohio matched from comp.sys.ibm.pc.hardware class
# Word ohio matched from rec.motorcycles class
# Word ohio matched from talk.politics.guns class
# Word ohio matched from misc.forsale class
# Word ohio matched from alt.atheism class
# Word ohio matched from talk.politics.misc class
# Word ohio matched from talk.politics.mideast class
# Word ohio matched from rec.autos class
# Word ohio matched from comp.windows.x class
# Word ohio matched from sci.crypt class
# Word ohio matched from sci.electronics class
# Word ohio matched from soc.religion.christian class
# Word ohio matched from rec.sport.hockey class
# Word ohio matched from comp.os.ms-windows.misc class
# Word ohio matched from sci.space class
# Word ohio matched from comp.sys.mac.hardware class
# Word ohio matched from sci.med class
# Word organization matched from comp.graphics class
# Word organization matched from talk.religion.misc class
# Word organization matched from rec.sport.baseball class
# Word organization matched from comp.sys.ibm.pc.hardware class
# Word organization matched from rec.motorcycles class
# Word organization matched from talk.politics.guns class
# Word organization matched from misc.forsale class
# Word organization matched from alt.atheism class
# Word organization matched from talk.politics.misc class
# Word organization matched from talk.politics.mideast class
# Word organization matched from rec.autos class
# Word organization matched from comp.windows.x class
# Word organization matched from sci.crypt class
# Word organization matched from sci.electronics class
# Word organization matched from soc.religion.christian class
# Word organization matched from rec.sport.hockey class
# Word organization matched from comp.os.ms-windows.misc class
# Word organization matched from sci.space class
# Word organization matched from comp.sys.mac.hardware class
# Word organization matched from sci.med class
# Word oz matched from comp.graphics class
# Word oz matched from talk.religion.misc class
# Word oz matched from rec.sport.baseball class
# Word oz matched from comp.sys.ibm.pc.hardware class
# Word oz matched from rec.motorcycles class
# Word oz matched from talk.politics.guns class
# Word oz matched from misc.forsale class
# Word oz matched from alt.atheism class
# Word oz matched from talk.politics.mideast class
# Word oz matched from rec.autos class
# Word oz matched from comp.windows.x class
# Word oz matched from sci.crypt class
# Word oz matched from sci.electronics class
# Word oz matched from soc.religion.christian class
# Word oz matched from rec.sport.hockey class
# Word oz matched from comp.os.ms-windows.misc class
# Word oz matched from sci.space class
# Word oz matched from comp.sys.mac.hardware class
# Word oz matched from sci.med class
# Word path matched from comp.graphics class
# Word path matched from talk.religion.misc class
# Word path matched from rec.sport.baseball class
# Word path matched from comp.sys.ibm.pc.hardware class
# Word path matched from rec.motorcycles class
# Word path matched from talk.politics.guns class
# Word path matched from misc.forsale class
# Word path matched from alt.atheism class
# Word path matched from talk.politics.misc class
# Word path matched from talk.politics.mideast class
# Word path matched from rec.autos class
# Word path matched from comp.windows.x class
# Word path matched from sci.crypt class
# Word path matched from sci.electronics class
# Word path matched from soc.religion.christian class
# Word path matched from rec.sport.hockey class
# Word path matched from comp.os.ms-windows.misc class
# Word path matched from sci.space class
# Word path matched from comp.sys.mac.hardware class
# Word path matched from sci.med class
# Word phillip matched from comp.graphics class
# Word playing matched from comp.graphics class
# Word playing matched from talk.religion.misc class
# ...
# Word sender matched from misc.forsale class
# Word sender matched from alt.atheism class
# Word sender matched from talk.politics.misc class
# Word sender matched from talk.politics.mideast class
# Word sender matched from rec.autos class
# Word sender matched from comp.windows.x class
# Word sender matched from sci.crypt class
# Word sender matched from sci.electronics class
# Word sender matched from soc.religion.christian class
# Word sender matched from rec.sport.hockey class
# Word sender matched from comp.os.ms-windows.misc class
# Word sender matched from sci.space class
# Word sender matched from comp.sys.mac.hardware class
# Word sender matched from sci.med class
# Word sites matched from comp.graphics class
# Word sites matched from comp.sys.ibm.pc.hardware class
# Word sites matched from rec.motorcycles class
# Word sites matched from talk.politics.guns class
# Word sites matched from alt.atheism class
# Word sites matched from talk.politics.misc class
# Word sites matched from talk.politics.mideast class
# Word sites matched from comp.windows.x class
# Word sites matched from sci.crypt class
# Word sites matched from sci.electronics class
# Word sites matched from rec.sport.hockey class
# Word sites matched from comp.os.ms-windows.misc class
# Word sites matched from sci.space class
# Word sites matched from comp.sys.mac.hardware class
# Word sites matched from sci.med class
# Word source matched from comp.graphics class
# Word source matched from talk.religion.misc class
# Word source matched from rec.sport.baseball class
# Word source matched from comp.sys.ibm.pc.hardware class
# Word source matched from rec.motorcycles class
# Word source matched from talk.politics.guns class
# Word source matched from misc.forsale class
# Word source matched from alt.atheism class
# Word source matched from talk.politics.misc class
# Word source matched from talk.politics.mideast class
# Word source matched from rec.autos class
# Word source matched from comp.windows.x class
# Word source matched from sci.crypt class
# Word source matched from sci.electronics class
# Word source matched from soc.religion.christian class
# Word source matched from rec.sport.hockey class
# Word source matched from comp.os.ms-windows.misc class
# Word source matched from sci.space class
# Word source matched from comp.sys.mac.hardware class
# Word source matched from sci.med class
# Word specific matched from comp.graphics class
# Word specific matched from talk.religion.misc class
# Word specific matched from rec.sport.baseball class
# Word specific matched from comp.sys.ibm.pc.hardware class
# Word specific matched from rec.motorcycles class
# Word specific matched from talk.politics.guns class
# Word specific matched from misc.forsale class
# Word specific matched from alt.atheism class
# Word specific matched from talk.politics.misc class
# Word specific matched from talk.politics.mideast class
# Word specific matched from rec.autos class
# Word specific matched from comp.windows.x class
# Word specific matched from sci.crypt class
# Word specific matched from sci.electronics class
# Word specific matched from soc.religion.christian class
# Word specific matched from rec.sport.hockey class
# Word specific matched from comp.os.ms-windows.misc class
# Word specific matched from sci.space class
# Word specific matched from comp.sys.mac.hardware class
# Word specific matched from sci.med class
# Word srv matched from comp.graphics class
# Word srv matched from talk.religion.misc class
# Word srv matched from rec.sport.baseball class
# Word srv matched from comp.sys.ibm.pc.hardware class
# Word srv matched from rec.motorcycles class
# Word srv matched from talk.politics.guns class
# Word srv matched from misc.forsale class
# Word srv matched from alt.atheism class
# Word srv matched from talk.politics.misc class
# Word srv matched from talk.politics.mideast class
# Word srv matched from rec.autos class
# Word srv matched from comp.windows.x class
# Word srv matched from sci.crypt class
# Word srv matched from sci.electronics class
# Word srv matched from soc.religion.christian class
# Word srv matched from rec.sport.hockey class
# Word srv matched from comp.os.ms-windows.misc class
# Word srv matched from sci.space class
# Word srv matched from comp.sys.mac.hardware class
# Word srv matched from sci.med class
# Word state matched from comp.graphics class
# Word state matched from talk.religion.misc class
# Word state matched from rec.sport.baseball class
# Word state matched from comp.sys.ibm.pc.hardware class
# Word state matched from rec.motorcycles class
# Word state matched from talk.politics.guns class
# Word state matched from misc.forsale class
# Word state matched from alt.atheism class
# Word state matched from talk.politics.misc class
# Word state matched from talk.politics.mideast class
# Word state matched from rec.autos class
# Word state matched from comp.windows.x class
# Word state matched from sci.crypt class
# Word state matched from sci.electronics class
# Word state matched from soc.religion.christian class
# Word state matched from rec.sport.hockey class
# Word state matched from comp.os.ms-windows.misc class
# Word state matched from sci.space class
# Word state matched from comp.sys.mac.hardware class
# Word state matched from sci.med class
# Word subject matched from comp.graphics class
# Word subject matched from talk.religion.misc class
# Word subject matched from rec.sport.baseball class
# Word subject matched from comp.sys.ibm.pc.hardware class
# Word subject matched from rec.motorcycles class
# Word subject matched from talk.politics.guns class
# Word subject matched from misc.forsale class
# Word subject matched from alt.atheism class
# Word subject matched from talk.politics.misc class
# Word subject matched from talk.politics.mideast class
# Word subject matched from rec.autos class
# Word subject matched from comp.windows.x class
# Word subject matched from sci.crypt class
# Word subject matched from sci.electronics class
# Word subject matched from soc.religion.christian class
# Word subject matched from rec.sport.hockey class
# Word subject matched from comp.os.ms-windows.misc class
# Word subject matched from sci.space class
# Word subject matched from comp.sys.mac.hardware class
# Word subject matched from sci.med class
# Word sure matched from comp.graphics class
# Word sure matched from talk.religion.misc class
# Word sure matched from rec.sport.baseball class
# Word sure matched from comp.sys.ibm.pc.hardware class
# Word sure matched from rec.motorcycles class
# Word sure matched from talk.politics.guns class
# Word sure matched from misc.forsale class
# Word sure matched from alt.atheism class
# Word sure matched from talk.politics.misc class
# Word sure matched from talk.politics.mideast class
# Word sure matched from rec.autos class
# Word sure matched from comp.windows.x class
# Word sure matched from sci.crypt class
# Word sure matched from sci.electronics class
# Word sure matched from soc.religion.christian class
# Word sure matched from rec.sport.hockey class
# Word sure matched from comp.os.ms-windows.misc class
# Word sure matched from sci.space class
# Word sure matched from comp.sys.mac.hardware class
# Word sure matched from sci.med class
# Word thanks matched from comp.graphics class
# Word thanks matched from talk.religion.misc class
# Word thanks matched from rec.sport.baseball class
# Word thanks matched from comp.sys.ibm.pc.hardware class
# Word thanks matched from rec.motorcycles class
# Word thanks matched from talk.politics.guns class
# Word thanks matched from misc.forsale class
# Word thanks matched from alt.atheism class
# Word thanks matched from talk.politics.misc class
# Word thanks matched from talk.politics.mideast class
# Word thanks matched from rec.autos class
# Word thanks matched from comp.windows.x class
# Word thanks matched from sci.crypt class
# Word thanks matched from sci.electronics class
# Word thanks matched from soc.religion.christian class
# Word thanks matched from rec.sport.hockey class
# Word thanks matched from comp.os.ms-windows.misc class
# Word thanks matched from sci.space class
# Word thanks matched from comp.sys.mac.hardware class
# Word thanks matched from sci.med class
# Word things matched from comp.graphics class
# Word things matched from talk.religion.misc class
# Word things matched from rec.sport.baseball class
# Word things matched from comp.sys.ibm.pc.hardware class
# Word things matched from rec.motorcycles class
# Word things matched from talk.politics.guns class
# Word things matched from misc.forsale class
# Word things matched from alt.atheism class
# Word things matched from talk.politics.misc class
# Word things matched from talk.politics.mideast class
# Word things matched from rec.autos class
# Word things matched from comp.windows.x class
# Word things matched from sci.crypt class
# Word things matched from sci.electronics class
# Word things matched from soc.religion.christian class
# Word things matched from rec.sport.hockey class
# Word things matched from comp.os.ms-windows.misc class
# Word things matched from sci.space class
# Word things matched from comp.sys.mac.hardware class
# Word things matched from sci.med class
# Word ucsd matched from comp.graphics class
# Word ucsd matched from talk.religion.misc class
# Word ucsd matched from rec.sport.baseball class
# Word ucsd matched from comp.sys.ibm.pc.hardware class
# Word ucsd matched from rec.motorcycles class
# Word ucsd matched from talk.politics.guns class
# Word ucsd matched from misc.forsale class
# Word ucsd matched from alt.atheism class
# Word ucsd matched from talk.politics.misc class
# Word ucsd matched from talk.politics.mideast class
# Word ucsd matched from rec.autos class
# Word ucsd matched from comp.windows.x class
# Word ucsd matched from sci.crypt class
# Word ucsd matched from sci.electronics class
# Word ucsd matched from soc.religion.christian class
# Word ucsd matched from rec.sport.hockey class
# Word ucsd matched from comp.os.ms-windows.misc class
# Word ucsd matched from sci.space class
# Word ucsd matched from comp.sys.mac.hardware class
# Word ucsd matched from sci.med class
# Word using matched from comp.graphics class
# Word using matched from talk.religion.misc class
# Word using matched from rec.sport.baseball class
# Word using matched from comp.sys.ibm.pc.hardware class
# Word using matched from rec.motorcycles class
# Word using matched from talk.politics.guns class
# Word using matched from misc.forsale class
# Word using matched from alt.atheism class
# Word using matched from talk.politics.misc class
# Word using matched from talk.politics.mideast class
# Word using matched from rec.autos class
# Word using matched from comp.windows.x class
# Word using matched from sci.crypt class
# Word using matched from sci.electronics class
# Word using matched from soc.religion.christian class
# Word using matched from rec.sport.hockey class
# Word using matched from comp.os.ms-windows.misc class
# Word using matched from sci.space class
# Word using matched from comp.sys.mac.hardware class
# Word using matched from sci.med class
# Word vax matched from comp.graphics class
# Word vax matched from talk.religion.misc class
# Word vax matched from rec.sport.baseball class
# Word vax matched from comp.sys.ibm.pc.hardware class
# Word vax matched from rec.motorcycles class
# Word vax matched from talk.politics.guns class
# Word vax matched from misc.forsale class
# Word vax matched from alt.atheism class
# Word vax matched from talk.politics.misc class
# Word vax matched from talk.politics.mideast class
# Word vax matched from rec.autos class
# Word vax matched from comp.windows.x class
# Word vax matched from sci.crypt class
# Word vax matched from sci.electronics class
# Word vax matched from soc.religion.christian class
# Word vax matched from rec.sport.hockey class
# Word vax matched from comp.os.ms-windows.misc class
# Word vax matched from sci.space class
# Word vax matched from comp.sys.mac.hardware class
# Word vax matched from sci.med class
# Word ve matched from comp.graphics class
# Word ve matched from talk.religion.misc class
# Word ve matched from rec.sport.baseball class
# Word ve matched from comp.sys.ibm.pc.hardware class
# Word ve matched from rec.motorcycles class
# Word ve matched from talk.politics.guns class
# Word ve matched from misc.forsale class
# Word ve matched from alt.atheism class
# Word ve matched from talk.politics.misc class
# Word ve matched from talk.politics.mideast class
# Word ve matched from rec.autos class
# Word ve matched from comp.windows.x class
# Word ve matched from sci.crypt class
# Word ve matched from sci.electronics class
# Word ve matched from soc.religion.christian class
# Word ve matched from rec.sport.hockey class
# Word ve matched from comp.os.ms-windows.misc class
# Word ve matched from sci.space class
# Word ve matched from comp.sys.mac.hardware class
# Word ve matched from sci.med class
# Word version matched from comp.graphics class
# Word version matched from talk.religion.misc class
# Word version matched from rec.sport.baseball class
# Word version matched from comp.sys.ibm.pc.hardware class
# Word version matched from rec.motorcycles class
# Word version matched from talk.politics.guns class
# Word version matched from misc.forsale class
# Word version matched from alt.atheism class
# Word version matched from talk.politics.misc class
# Word version matched from talk.politics.mideast class
# Word version matched from rec.autos class
# Word version matched from comp.windows.x class
# Word version matched from sci.crypt class
# Word version matched from sci.electronics class
# Word version matched from soc.religion.christian class
# Word version matched from rec.sport.hockey class
# Word version matched from comp.os.ms-windows.misc class
# Word version matched from sci.space class
# Word version matched from comp.sys.mac.hardware class
# Word version matched from sci.med class
# Word victoria matched from comp.graphics class
# Word victoria matched from talk.religion.misc class
# Word victoria matched from rec.sport.baseball class
# Word victoria matched from comp.sys.ibm.pc.hardware class
# Word victoria matched from rec.motorcycles class
# Word victoria matched from talk.politics.guns class
# Word victoria matched from rec.autos class
# Word victoria matched from sci.electronics class
# Word victoria matched from soc.religion.christian class
# Word victoria matched from rec.sport.hockey class
# Word victoria matched from comp.sys.mac.hardware class
# Word work matched from comp.graphics class
# Word work matched from talk.religion.misc class
# Word work matched from rec.sport.baseball class
# Word work matched from comp.sys.ibm.pc.hardware class
# Word work matched from rec.motorcycles class
# Word work matched from talk.politics.guns class
# Word work matched from misc.forsale class
# Word work matched from alt.atheism class
# Word work matched from talk.politics.misc class
# Word work matched from talk.politics.mideast class
# Word work matched from rec.autos class
# Word work matched from comp.windows.x class
# Word work matched from sci.crypt class
# Word work matched from sci.electronics class
# Word work matched from soc.religion.christian class
# Word work matched from rec.sport.hockey class
# Word work matched from comp.os.ms-windows.misc class
# Word work matched from sci.space class
# Word work matched from comp.sys.mac.hardware class
# Word work matched from sci.med class
# Word zaphod matched from comp.graphics class
# Word zaphod matched from talk.religion.misc class
# Word zaphod matched from rec.sport.baseball class
# Word zaphod matched from comp.sys.ibm.pc.hardware class
# Word zaphod matched from rec.motorcycles class
# Word zaphod matched from talk.politics.guns class
# Word zaphod matched from misc.forsale class
# Word zaphod matched from alt.atheism class
# Word zaphod matched from talk.politics.misc class
# Word zaphod matched from talk.politics.mideast class
# Word zaphod matched from rec.autos class
# Word zaphod matched from comp.windows.x class
# Word zaphod matched from sci.crypt class
# Word zaphod matched from sci.electronics class
# Word zaphod matched from soc.religion.christian class
# Word zaphod matched from rec.sport.hockey class
# Word zaphod matched from comp.os.ms-windows.misc class
# Word zaphod matched from sci.space class
# Word zaphod matched from comp.sys.mac.hardware class
# Word zaphod matched from sci.med class
# Training Accuracy : 0.0
